# %%
import pandas as pd
df_csv=pd.read_csv('DATASET.csv')
df_csv.head()
# Out:
#    S.NO     ROLL NO     NAME BRANCH SECTION  CGPA
# 0     1  25wh1a05a5   Hasini    CSE       C  9.80
# 1     2  25wh1a05v3  Nikitha   AIML       A  8.50
# 2     3  25wh1a05h5   Vishnu    ECE       B  8.95
# 3     4  25wh1a05bb    Divya    EEE       A  9.20
# 4     5  25wh1a05bc    Navya    CSE       F  8.75
